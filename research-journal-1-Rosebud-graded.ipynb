# %% [markdown]
# # Research Notebook
# ## Rosebud John
# ## Date: 19 January 2026

# %% [markdown]
# # 1. Experience
# ## 1.1 Describe at least one research activity you worked on this week.
#
# - Finished settting up access to COSMA.
# - Coded position - position and velocity - velocity plots to ensure that simulation data is being accessed successfully.
# - Attended weekly group meeting to give updates and discuss further steps.
# - Read Calore et al.'s "Simulated Milky Way analogues: implications for dark matter indirect searches" to understand how to plot a rotation curve.
# - Initiated plan for rotation curves.
#
# ## 1.2 Motivation:
# Plotting a position - position and velocity - velocity plots are a nice sanity check because it shows whether the program is behaving as expected and also is an easy way to famaliarize oneself with the programs. The position–position plot can reveal things such as asymmetries, offsets, or problems with centering or coordinate handling. Similarly, the velocity–velocity plot helps check whether the velocity components are well behaved. Correlations in these plots suggest that the simulation data have been processed successfully. For the LMC, this helps assess whether the spatial and kinematic structure resembles a rotating spherical galaxy rather than a disrupted or unphysical system.

# %% [markdown]
# # 2: What? (What happened?)
# ## 2.1 Describe what happened during your activities for the week.
#
# I finished setting up access through COSMA, following procedures to allow COSMA to access my laptop's routes, which was completed successfully. I wrote code to plot position - position and velocity - velocity plots. The data is retrived through code provided which was previously written by Evan. The retrival code defines several functions and conditions to make lists of data and also allows to access specific sets given the 'snaptar' which is basically the snapshot of the Milky Way one is instrested to look at. Below is a sample of an X and Y position- position and velocity - velocity graph resectively.
#
# ```
# # position - position
# x=coord[:, 0]
# y = coord[:, 1]
# py.scatter(x, y, s=10)
# py.xlabel("position along x (km/s)")
# py.ylabel("position along y (km/s)")
# py.show()
#
# # velocity - velocity
# vx=vel_dm[:, 0]
# vy = vel_dm[:, 1]
# py.scatter(vx, vy, s=10, alpha = 1)
# py.xlabel("velocity along x (km/s)")
# py.ylabel("velocity along y (km/s)")
# py.show()
# ```
# The successful plotting of graphs show that the data is being fetched from the right places into the right places.
#
# For the rotation curves, I have just developed a 'plan of action', analysing Calore et al.'s methodolody in section 3.1. The DM halo rotation curve will plot ω(R) vs R, where ω(R) is the angular circular velocity. ω(R) is given by
# $$ ω(R) = \frac{v(R)}{R} $$
# where v(R) is the circular velocity, given by
# $$ v(R) = \frac{\sqrt{GM(<R)}}{R)} $$
# M(<R) is the mass enclosed in R. R is the galactocentric distance give by the distance formula,
# $$ R= \sqrt{x^2+y^2+z^2}$$

# %% [markdown]
# # 3: So what? (What does it mean?)
# ## 3.1 Describe your results
# <img src="attachment:11fc5802-09b9-4a28-ac23-ae198bdbb8a4.png" width="350">
#
# *Figure 1: position - position plot of x and y direction values for the present day snapshot*
#
# <img src="attachment:4e9af7b7-ac26-4409-b012-5e0f75735e32.png" width="350">
#
# *Figure 2: veloctiy - velocity plot of x and y direction values for the present day snapshot*
#
# Figure 1 shows a position - position curve for the present day snapshot for the x direction values.
# The x–y plot shows that the galaxy is spread out more in one direction and is not perfectly circular. The tilted shape means the galaxy could be rotated relative to the coordinate axes The y–z and x–z plots looking similar supports this, showing the galaxy has a roughly symmetric shape in 3D. The plots for the infall snapshot look very similar, except they appear to be more dense around the (0,0) region.
#
# Figure 2 shows a velocity - velocity curve for the present day snapshot for the x direction values. The nearly circular shape means that particle motions are mostly random and similar in all directions, indicating little net rotation. The present-day snapshot being slightly oval suggests that some ordered rotational motion has developed over time, but random motions are still important in supporting the system.

# %% [markdown]
# # 4. Now what? (What's next?)
# ## 4.1 Plan for the next week
#
# I achieved the intended goal of plotting position - position and velocity - velocity plots for both snapshots. Next week I plan on plotting the rotation curve by writing the code for it, using Calore et al.'s paper as a reference.

# %% [markdown]
# # 5. Bibliography
#
# [1] Calore et al., *Simulated Milky Way analogues: implications for dark matter indirect searches*, JCAP 12, 053 (2015) [arXiv:1509.02164 [astro-ph.GA]]

# %% [markdown]
# | Category       | Points      |
# | ------------- |:------------:|
# | Formatting    |       2 / 2       |
# | Experience    |       2 / 2       |
# | What?         |       2 / 2       |
# | So what?      |       4 / 4       |
# | Now what?     |       4 / 4       |
# | Bibliography  |       3 / 3     |
# | Style         |       3 / 3       |
# | Total         |       20 / 20   |
